# %%
Calcular el volumen:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import symbols, integrate

# %%
x, y, z = symbols('x y z')

# %%
volumen = integrate(x+y, (z,0,4-y**2), (y,0,2-x), (x,0,2))

# %%
print('volumen=', volumen)
# Out:
# volumen= 128/15
